# %% [markdown]
# # Single Phase Flow Examples

# %% [markdown]
# <a id='table'></a>

# %% [markdown]
# ## Examples
#
# - [Example 1. Boundary conditions](#ex1)
# <img src=".\images\ex1.gif">
#
# - [Example 2. Three injectors and one producer](#ex2)
# <img src=".\images\ex2.gif">

# %%
from modules.simulator.simulator import *
from modules.simulator.two_phase_flow import *
from modules.simulator.simplots import *
from modules.simulator.units import UnitRegistry
import numpy as np

# Set image folder path
imgpath = ".\\images"
# Units
u = UnitRegistry()

# %% [markdown]
# <a id='ex1'></a>

# %%
# Same fluid for all the examples
# FLUID
cf = 5E-5 / u.psi
miu = lambda p:  1.0 * np.exp(5E-5 * (p/u.psi -2800)) * u.centi * u.poise
rho = lambda p: 800 * np.exp(cf * (p - 15 * u.psi) )  * u.kilogram/ u.meter**3
fvf = lambda p: 1.0 * np.exp(- cf * (p - 15 * u.psi) )   # adimensional
fluid = singleFluid(miu, rho, fvf, cf)

# %% [markdown]
# ## [Example 1. Boundary conditions](#table)
#
# In this example there is a single rock layer. The layer is 5 cells by 30 cells. It has a constant pressure in the West face of 3000 psi and a pressure of 2900 in the East face. The initial pressure is 3000 psi for all the cells. The simulation is run for 20 timesteps of 0.01 days with the Lagging Coefficient Solver.

# %%
# GRID
Nx, Ny, Nz = np.array([5, 30, 1])
Sx, Sy, Sz = np.array([1, 1, 1]) * 0.1 * u.meter
depth = np.hstack((Sz * 1 * np.ones([Nx * Ny, ])))
grid = uniformCartesianGrid(Nx, Ny, Nz, Sx, Sy, Sz, depth)

# ROCK
poro = np.random.random_sample(grid.cellnumber)
perm = 5 * np.random.random_sample(grid.cellnumber) * u.milli * u.darcy
cr = 3E-6 / u.psi
porofunc = lambda p: poro * np.exp(cr * (p - 2800 * u.psi))
rock = Rock(perm, poro, cr, porofunc)

# SCHEDULE
timesteps = 0.01 * np.ones(20) *u.day
sch = Schedule(timesteps)

# SOURCE TERM
source_empty = np.zeros([grid.cellnumber, 1])

# BOUNDARY
boundary = Boundary()
# North side of reservoir has a constant  pressure of 2300 psi
boundary.set_boundary_condition('W', 'constant-pressure', 3000 * u.psi)
boundary.set_boundary_condition('E', 'constant-pressure', 2900 * u.psi)

# Set initial conditions
p_init = 3000 * u.psi * np.ones([grid.cellnumber, ])

# WELLS
# Empty wells term
wells_empty = Wells(grid, rock, fluid)

# Initilize solver
LCM = LaggingCoefficients(
    grid, rock, fluid, wells_empty, source_empty, p_init, boundary, gravity=True)

# Run simulation
r, well_solution, sch = LCM.solve(sch, max_inner_iter = 2, tol = 1E-6, ATS = False)

# Transform units to psi
p = r/u.psi

# We will  save a plot for each timestep and then use 
# ffmpeg to create a gif
acum_sum = np.cumsum(sch.timesteps) / u.day
# Add "0" for the initial conditions
acum_sum = np.hstack((0, acum_sum))

for k in np.arange(0,acum_sum.size, 1): 
    plotCellValues2D(grid, p[:, k], 'inferno', np.min(p), np.max(p),
                     title='Pressure (psi). {:.3f} days'.format(acum_sum[k]), 
                     filename='{}\\ex1_{}'.format(imgpath, k))
# Out:
# Solving timestep 1 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 2 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 3 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 4 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 5 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 6 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 7 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 8 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 9 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 10 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 11 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 12 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 13 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 14 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 15 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 16 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 17 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 18 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 19 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2
# Solving timestep 20 / 20
# 	 Inner loop 1 / 2
# 	 Inner loop 2 / 2

# %% [markdown]
# <a id='ex2'></a>

# %% [markdown]
# ## [Example 2. Three injectors and one producer.](#table)
#
# In this example there are three layers of rock, each one with measures of 10 by 10 cells. Each cell is a cube with a side of 1 meter. There are three injectors and one producer well in the bottom layer. The simulation is run for 2 days with the Fully Implicit Method.

# %%
# GRID
Nx, Ny, Nz = np.array([10, 10, 3])
Sx, Sy, Sz = np.array([1, 1, 1]) * 1 * u.meter
depth = np.hstack((Sz * 1 * np.ones([Nx * Ny, ]), 
                  Sz * 1 * np.ones([Nx * Ny, ]),
                  Sz * 1 * np.ones([Nx * Ny, ])))

grid = uniformCartesianGrid(Nx, Ny, Nz, Sx, Sy, Sz, depth)

# ROCK
poro = np.random.random_sample(grid.cellnumber)
perm = 10 * np.random.random_sample(grid.cellnumber) * u.milli * u.darcy
cr = 3E-6 / u.psi
porofunc = lambda p: poro * np.exp(cr * (p - 2800 * u.psi))
rock = Rock(perm, poro, cr, porofunc)

#SOURCE
source2 = np.zeros([grid.cellnumber, 1])
source2[25] = -2 * u.barrel/u.hour
source2[50] = -2 * u.barrel/u.hour
source2[9] = -1 * u.barrel/u.hour

# INITIAL CONDITIONS
p_init = 3000 * u.psi * np.ones([grid.cellnumber, ])

# --- WELLS
wells = Wells(grid, rock, fluid)
wells.add_vertical_well(0.35 * u.feet, 99, 2500 * u.psi, 0, 'Producer 1' )

# --- Initilize simulator
# SCHEDULE
timesteps = 0.01 * np.ones(200) *u.day
sch = Schedule(timesteps)

FIM  = ImplicitAnalytic(
    grid, rock, fluid, wells, source2, p_init, empty_boundary, gravity=True)

r, well_solution = FIM.solve(sch)

# Transform units to psi
p = r/u.psi

# We will  save a plot for each timestep and then use 
# ffmpeg to create a gif
acum_sum = np.cumsum(sch.timesteps) / u.day
acum_sum = np.hstack((0, acum_sum))

for k in np.arange(0, acum_sum.size, 1):
    plotCellValues2D(grid, p[:, k], 'inferno', np.min(p), np.max(p),
                     title='Pressure (psi). {:.3f} days'.format(acum_sum[k]), 
                     filename='{}\\ex2_{}'.format(imgpath, k))
# Out:
# Solving timestep 1  / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.02E-02
#  	 Newton-Raphson solver :  2/10. Error: 9.40E-06
#  	 Newton-Raphson solver :  3/10. Error: 1.19E-09
#  	 Newton-Raphson solver :  4/10. Error: 1.79E-13
# Solving timestep 2  / 200
#  	 Newton-Raphson solver :  1/10. Error: 1.11E-02
#  	 Newton-Raphson solver :  2/10. Error: 2.52E-06
#  	 Newton-Raphson solver :  3/10. Error: 1.06E-10
#  	 Newton-Raphson solver :  4/10. Error: 9.50E-15
# Solving timestep 3  / 200
#  	 Newton-Raphson solver :  1/10. Error: 8.76E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.05E-06
#  	 Newton-Raphson solver :  3/10. Error: 6.45E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.67E-15
# Solving timestep 4  / 200
#  	 Newton-Raphson solver :  1/10. Error: 7.83E-03
#  	 Newton-Raphson solver :  2/10. Error: 7.49E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.20E-11
#  	 Newton-Raphson solver :  4/10. Error: 3.20E-15
# Solving timestep 5  / 200
#  	 Newton-Raphson solver :  1/10. Error: 7.33E-03
#  	 Newton-Raphson solver :  2/10. Error: 6.85E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.14E-11
#  	 Newton-Raphson solver :  4/10. Error: 7.79E-15
# Solving timestep 6  / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.99E-03
#  	 Newton-Raphson solver :  2/10. Error: 5.80E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.33E-11
#  	 Newton-Raphson solver :  4/10. Error: 6.18E-15
# Solving timestep 7  / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.75E-03
#  	 Newton-Raphson solver :  2/10. Error: 6.35E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.98E-11
#  	 Newton-Raphson solver :  4/10. Error: 6.26E-15
# Solving timestep 8  / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.56E-03
#  	 Newton-Raphson solver :  2/10. Error: 4.70E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.32E-11
#  	 Newton-Raphson solver :  4/10. Error: 4.98E-15
# Solving timestep 9  / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.41E-03
#  	 Newton-Raphson solver :  2/10. Error: 4.61E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.02E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.48E-15
# Solving timestep 10 / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.28E-03
#  	 Newton-Raphson solver :  2/10. Error: 4.49E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.30E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.24E-15
# Solving timestep 11 / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.16E-03
#  	 Newton-Raphson solver :  2/10. Error: 4.04E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.10E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.09E-15
# Solving timestep 12 / 200
#  	 Newton-Raphson solver :  1/10. Error: 6.07E-03
#  	 Newton-Raphson solver :  2/10. Error: 4.59E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.54E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.72E-15
# Solving timestep 13 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.98E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.88E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.71E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.08E-15
# Solving timestep 14 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.90E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.70E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.97E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.64E-15
# Solving timestep 15 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.82E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.92E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.89E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.25E-15
# Solving timestep 16 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.75E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.58E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.35E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.05E-15
# Solving timestep 17 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.69E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.37E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.86E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.79E-15
# Solving timestep 18 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.63E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.53E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.36E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.71E-16
# Solving timestep 19 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.57E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.41E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.59E-11
#  	 Newton-Raphson solver :  4/10. Error: 3.58E-15
# Solving timestep 20 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.52E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.17E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.76E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.95E-16
# Solving timestep 21 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.46E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.31E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.25E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.91E-15
# Solving timestep 22 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.41E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.14E-07
#  	 Newton-Raphson solver :  3/10. Error: 9.00E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.83E-16
# Solving timestep 23 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.37E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.02E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.34E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.66E-16
# Solving timestep 24 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.32E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.07E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.14E-11
#  	 Newton-Raphson solver :  4/10. Error: 4.78E-15
# Solving timestep 25 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.27E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.45E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.39E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.66E-15
# Solving timestep 26 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.23E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.96E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.22E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.42E-16
# Solving timestep 27 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.19E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.93E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.29E-11
#  	 Newton-Raphson solver :  4/10. Error: 6.44E-16
# Solving timestep 28 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.14E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.91E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.23E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.61E-16
# Solving timestep 29 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.10E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.82E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.97E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.22E-15
# Solving timestep 30 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.06E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.74E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.22E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.15E-15
# Solving timestep 31 / 200
#  	 Newton-Raphson solver :  1/10. Error: 5.02E-03
#  	 Newton-Raphson solver :  2/10. Error: 3.15E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.16E-11
#  	 Newton-Raphson solver :  4/10. Error: 6.35E-16
# Solving timestep 32 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.99E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.73E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.10E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.31E-16
# Solving timestep 33 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.95E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.98E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.41E-11
#  	 Newton-Raphson solver :  4/10. Error: 7.63E-16
# Solving timestep 34 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.91E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.80E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.82E-11
#  	 Newton-Raphson solver :  4/10. Error: 3.76E-15
# Solving timestep 35 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.87E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.70E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.15E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.12E-16
# Solving timestep 36 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.84E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.61E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.27E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.05E-16
# Solving timestep 37 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.80E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.59E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.11E-11
#  	 Newton-Raphson solver :  4/10. Error: 7.50E-16
# Solving timestep 38 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.77E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.55E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.62E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.05E-16
# Solving timestep 39 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.73E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.53E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.05E-11
#  	 Newton-Raphson solver :  4/10. Error: 6.63E-16
# Solving timestep 40 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.70E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.54E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.68E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.91E-16
# Solving timestep 41 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.67E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.66E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.25E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.10E-16
# Solving timestep 42 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.63E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.46E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.00E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.63E-16
# Solving timestep 43 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.60E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.63E-07
#  	 Newton-Raphson solver :  3/10. Error: 9.58E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.36E-16
# Solving timestep 44 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.57E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.44E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.21E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.82E-16
# Solving timestep 45 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.54E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.49E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.16E-11
#  	 Newton-Raphson solver :  4/10. Error: 4.14E-16
# Solving timestep 46 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.50E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.35E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.13E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.09E-16
# Solving timestep 47 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.47E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.36E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.39E-11
#  	 Newton-Raphson solver :  4/10. Error: 8.36E-16
# Solving timestep 48 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.44E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.42E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.40E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.41E-15
# Solving timestep 49 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.41E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.28E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.24E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.59E-16
# Solving timestep 50 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.38E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.26E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.12E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.57E-16
# Solving timestep 51 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.35E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.24E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.77E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.33E-16
# Solving timestep 52 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.32E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.38E-07
#  	 Newton-Raphson solver :  3/10. Error: 9.28E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.74E-16
# Solving timestep 53 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.30E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.20E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.88E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.64E-16
# Solving timestep 54 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.27E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.30E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.23E-11
#  	 Newton-Raphson solver :  4/10. Error: 7.77E-16
# Solving timestep 55 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.24E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.44E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.07E-11
#  	 Newton-Raphson solver :  4/10. Error: 4.19E-15
# Solving timestep 56 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.21E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.38E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.21E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.10E-16
# Solving timestep 57 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.18E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.19E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.67E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.54E-15
# Solving timestep 58 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.16E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.21E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.12E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.34E-15
# Solving timestep 59 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.13E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.07E-07
#  	 Newton-Raphson solver :  3/10. Error: 9.79E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.02E-16
# Solving timestep 60 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.10E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.11E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.09E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.33E-15
# Solving timestep 61 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.08E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.10E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.46E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.49E-16
# Solving timestep 62 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.05E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.22E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.05E-11
#  	 Newton-Raphson solver :  4/10. Error: 7.55E-16
# Solving timestep 63 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.02E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.10E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.56E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.63E-16
# Solving timestep 64 / 200
#  	 Newton-Raphson solver :  1/10. Error: 4.00E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.13E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.14E-11
#  	 Newton-Raphson solver :  4/10. Error: 8.59E-16
# Solving timestep 65 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.97E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.24E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.40E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.24E-15
# Solving timestep 66 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.95E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.16E-07
#  	 Newton-Raphson solver :  3/10. Error: 9.53E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.01E-15
# Solving timestep 67 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.92E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.12E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.12E-11
#  	 Newton-Raphson solver :  4/10. Error: 3.70E-15
# Solving timestep 68 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.90E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.09E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.59E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.15E-16
# Solving timestep 69 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.88E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.95E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.37E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.37E-16
# Solving timestep 70 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.85E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.98E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.69E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.00E-16
# Solving timestep 71 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.83E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.96E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.68E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.49E-15
# Solving timestep 72 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.80E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.90E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.72E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.47E-15
# Solving timestep 73 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.78E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.93E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.54E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.97E-16
# Solving timestep 74 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.76E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.85E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.80E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.31E-16
# Solving timestep 75 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.74E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.95E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.65E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.35E-16
# Solving timestep 76 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.71E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.84E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.11E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.09E-15
# Solving timestep 77 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.69E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.78E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.07E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.08E-15
# Solving timestep 78 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.67E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.77E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.34E-12
#  	 Newton-Raphson solver :  4/10. Error: 8.03E-16
# Solving timestep 79 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.65E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.82E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.64E-12
#  	 Newton-Raphson solver :  4/10. Error: 8.98E-16
# Solving timestep 80 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.62E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.84E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.22E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.55E-15
# Solving timestep 81 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.60E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.99E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.98E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.33E-15
# Solving timestep 82 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.58E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.92E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.39E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.85E-15
# Solving timestep 83 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.56E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.82E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.92E-11
#  	 Newton-Raphson solver :  4/10. Error: 3.45E-15
# Solving timestep 84 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.54E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.72E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.37E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.89E-16
# Solving timestep 85 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.52E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.80E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.38E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.91E-16
# Solving timestep 86 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.50E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.75E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.35E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.10E-16
# Solving timestep 87 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.48E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.72E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.66E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.65E-15
# Solving timestep 88 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.46E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.75E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.19E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.50E-16
# Solving timestep 89 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.44E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.69E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.30E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.13E-15
# Solving timestep 90 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.42E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.63E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.56E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.68E-16
# Solving timestep 91 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.40E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.61E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.09E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.67E-16
# Solving timestep 92 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.38E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.63E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.12E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.49E-16
# Solving timestep 93 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.36E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.66E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.87E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.78E-15
# Solving timestep 94 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.34E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.67E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.19E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.63E-16
# Solving timestep 95 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.32E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.74E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.20E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.03E-15
# Solving timestep 96 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.30E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.61E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.75E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.07E-15
# Solving timestep 97 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.29E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.66E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.78E-12
#  	 Newton-Raphson solver :  4/10. Error: 9.59E-16
# Solving timestep 98 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.27E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.72E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.77E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.02E-15
# Solving timestep 99 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.25E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.70E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.73E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.88E-15
# Solving timestep 100 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.23E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.62E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.70E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.72E-16
# Solving timestep 101 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.21E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.56E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.14E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.01E-16
# Solving timestep 102 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.20E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.48E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.73E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.53E-16
# Solving timestep 103 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.18E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.50E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.25E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.04E-15
# Solving timestep 104 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.16E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.54E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.29E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.93E-15
# Solving timestep 105 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.14E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.66E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.46E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.52E-15
# Solving timestep 106 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.13E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.50E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.23E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.29E-15
# Solving timestep 107 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.11E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.52E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.09E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.47E-15
# Solving timestep 108 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.09E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.54E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.62E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.70E-15
# Solving timestep 109 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.08E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.47E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.94E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.39E-16
# Solving timestep 110 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.06E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.44E-07
#  	 Newton-Raphson solver :  3/10. Error: 9.23E-12
#  	 Newton-Raphson solver :  4/10. Error: 7.32E-16
# Solving timestep 111 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.04E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.40E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.23E-12
#  	 Newton-Raphson solver :  4/10. Error: 7.63E-16
# Solving timestep 112 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.03E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.72E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.13E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.24E-16
# Solving timestep 113 / 200
#  	 Newton-Raphson solver :  1/10. Error: 3.01E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.44E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.15E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.08E-15
# Solving timestep 114 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.99E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.39E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.24E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.09E-16
# Solving timestep 115 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.98E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.43E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.44E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.29E-15
# Solving timestep 116 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.96E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.35E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.54E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.10E-16
# Solving timestep 117 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.95E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.33E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.91E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.22E-16
# Solving timestep 118 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.93E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.32E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.46E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.28E-16
# Solving timestep 119 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.92E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.36E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.96E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.53E-16
# Solving timestep 120 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.90E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.42E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.02E-11
#  	 Newton-Raphson solver :  4/10. Error: 8.07E-16
# Solving timestep 121 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.89E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.30E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.92E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.85E-16
# Solving timestep 122 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.87E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.32E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.01E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.29E-16
# Solving timestep 123 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.86E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.26E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.02E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.29E-16
# Solving timestep 124 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.84E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.40E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.22E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.77E-15
# Solving timestep 125 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.83E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.35E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.31E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.02E-15
# Solving timestep 126 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.81E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.38E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.07E-11
#  	 Newton-Raphson solver :  4/10. Error: 4.63E-16
# Solving timestep 127 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.80E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.31E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.62E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.37E-16
# Solving timestep 128 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.78E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.25E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.24E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.71E-16
# Solving timestep 129 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.77E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.35E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.42E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.90E-16
# Solving timestep 130 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.76E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.26E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.15E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.36E-16
# Solving timestep 131 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.74E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.34E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.24E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.95E-16
# Solving timestep 132 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.73E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.24E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.20E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.02E-16
# Solving timestep 133 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.71E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.21E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.91E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.69E-16
# Solving timestep 134 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.70E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.23E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.57E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.26E-16
# Solving timestep 135 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.69E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.21E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.85E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.94E-16
# Solving timestep 136 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.67E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.22E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.39E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.12E-16
# Solving timestep 137 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.66E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.29E-07
#  	 Newton-Raphson solver :  3/10. Error: 2.36E-11
#  	 Newton-Raphson solver :  4/10. Error: 2.13E-15
# Solving timestep 138 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.65E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.19E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.07E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.04E-16
# Solving timestep 139 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.63E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.19E-07
#  	 Newton-Raphson solver :  3/10. Error: 6.46E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.12E-16
# Solving timestep 140 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.62E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.15E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.80E-12
#  	 Newton-Raphson solver :  4/10. Error: 7.95E-16
# Solving timestep 141 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.61E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.16E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.19E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.40E-16
# Solving timestep 142 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.60E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.21E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.72E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.08E-16
# Solving timestep 143 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.58E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.08E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.32E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.06E-16
# Solving timestep 144 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.57E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.12E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.37E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.47E-16
# Solving timestep 145 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.56E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.07E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.14E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.97E-16
# Solving timestep 146 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.55E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.09E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.18E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.79E-16
# Solving timestep 147 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.53E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.12E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.50E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.31E-16
# Solving timestep 148 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.52E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.15E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.59E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.03E-16
# Solving timestep 149 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.51E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.12E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.88E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.59E-16
# Solving timestep 150 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.50E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.14E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.04E-11
#  	 Newton-Raphson solver :  4/10. Error: 6.17E-16
# Solving timestep 151 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.49E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.16E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.51E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.83E-16
# Solving timestep 152 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.47E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.08E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.84E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.99E-16
# Solving timestep 153 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.46E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.08E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.42E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.71E-16
# Solving timestep 154 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.45E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.06E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.55E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.49E-16
# Solving timestep 155 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.44E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.13E-07
#  	 Newton-Raphson solver :  3/10. Error: 7.44E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.27E-16
# Solving timestep 156 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.43E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.06E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.35E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.83E-16
# Solving timestep 157 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.42E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.08E-07
#  	 Newton-Raphson solver :  3/10. Error: 3.30E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.53E-16
# Solving timestep 158 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.40E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.08E-07
#  	 Newton-Raphson solver :  3/10. Error: 8.20E-12
#  	 Newton-Raphson solver :  4/10. Error: 7.79E-16
# Solving timestep 159 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.39E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.03E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.17E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.37E-15
# Solving timestep 160 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.38E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.11E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.11E-11
#  	 Newton-Raphson solver :  4/10. Error: 9.71E-16
# Solving timestep 161 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.37E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.04E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.34E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.81E-16
# Solving timestep 162 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.36E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.07E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.35E-11
#  	 Newton-Raphson solver :  4/10. Error: 8.40E-16
# Solving timestep 163 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.35E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.07E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.30E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.47E-16
# Solving timestep 164 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.34E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.03E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.48E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.59E-16
# Solving timestep 165 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.33E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.89E-08
#  	 Newton-Raphson solver :  3/10. Error: 5.10E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.96E-16
# Solving timestep 166 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.32E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.04E-07
#  	 Newton-Raphson solver :  3/10. Error: 4.65E-12
#  	 Newton-Raphson solver :  4/10. Error: 7.15E-16
# Solving timestep 167 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.31E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.74E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.47E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.27E-16
# Solving timestep 168 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.30E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.49E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.80E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.97E-16
# Solving timestep 169 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.28E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.85E-08
#  	 Newton-Raphson solver :  3/10. Error: 7.71E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.62E-16
# Solving timestep 170 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.27E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.59E-08
#  	 Newton-Raphson solver :  3/10. Error: 5.55E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.92E-16
# Solving timestep 171 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.26E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.59E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.89E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.65E-16
# Solving timestep 172 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.25E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.46E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.36E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.41E-16
# Solving timestep 173 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.24E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.03E-07
#  	 Newton-Raphson solver :  3/10. Error: 5.68E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.84E-16
# Solving timestep 174 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.23E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.11E-07
#  	 Newton-Raphson solver :  3/10. Error: 1.43E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.00E-15
# Solving timestep 175 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.22E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.62E-08
#  	 Newton-Raphson solver :  3/10. Error: 5.49E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.26E-16
# Solving timestep 176 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.21E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.51E-08
#  	 Newton-Raphson solver :  3/10. Error: 5.80E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.35E-16
# Solving timestep 177 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.20E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.37E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.01E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.44E-16
# Solving timestep 178 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.19E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.53E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.78E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.08E-16
# Solving timestep 179 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.18E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.38E-08
#  	 Newton-Raphson solver :  3/10. Error: 1.06E-11
#  	 Newton-Raphson solver :  4/10. Error: 5.53E-16
# Solving timestep 180 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.17E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.72E-08
#  	 Newton-Raphson solver :  3/10. Error: 7.93E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.89E-16
# Solving timestep 181 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.16E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.18E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.26E-12
#  	 Newton-Raphson solver :  4/10. Error: 7.64E-16
# Solving timestep 182 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.15E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.38E-08
#  	 Newton-Raphson solver :  3/10. Error: 9.93E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.06E-15
# Solving timestep 183 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.14E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.05E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.00E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.48E-16
# Solving timestep 184 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.14E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.97E-08
#  	 Newton-Raphson solver :  3/10. Error: 1.53E-11
#  	 Newton-Raphson solver :  4/10. Error: 7.31E-16
# Solving timestep 185 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.13E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.51E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.77E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.58E-16
# Solving timestep 186 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.12E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.60E-08
#  	 Newton-Raphson solver :  3/10. Error: 5.42E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.94E-16
# Solving timestep 187 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.11E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.48E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.67E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.24E-16
# Solving timestep 188 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.10E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.99E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.39E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.94E-16
# Solving timestep 189 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.09E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.71E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.60E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.72E-16
# Solving timestep 190 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.08E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.31E-08
#  	 Newton-Raphson solver :  3/10. Error: 8.31E-12
#  	 Newton-Raphson solver :  4/10. Error: 1.38E-15
# Solving timestep 191 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.07E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.75E-08
#  	 Newton-Raphson solver :  3/10. Error: 7.86E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.15E-16
# Solving timestep 192 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.06E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.34E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.00E-11
#  	 Newton-Raphson solver :  4/10. Error: 1.01E-15
# Solving timestep 193 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.05E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.68E-08
#  	 Newton-Raphson solver :  3/10. Error: 5.90E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.53E-16
# Solving timestep 194 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.04E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.12E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.54E-12
#  	 Newton-Raphson solver :  4/10. Error: 2.78E-16
# Solving timestep 195 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.03E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.77E-08
#  	 Newton-Raphson solver :  3/10. Error: 9.85E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.14E-16
# Solving timestep 196 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.03E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.08E-08
#  	 Newton-Raphson solver :  3/10. Error: 9.48E-12
#  	 Newton-Raphson solver :  4/10. Error: 6.56E-16
# Solving timestep 197 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.02E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.74E-08
#  	 Newton-Raphson solver :  3/10. Error: 6.93E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.01E-16
# Solving timestep 198 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.01E-03
#  	 Newton-Raphson solver :  2/10. Error: 7.95E-08
#  	 Newton-Raphson solver :  3/10. Error: 4.70E-12
#  	 Newton-Raphson solver :  4/10. Error: 5.42E-16
# Solving timestep 199 / 200
#  	 Newton-Raphson solver :  1/10. Error: 2.00E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.02E-08
#  	 Newton-Raphson solver :  3/10. Error: 7.88E-12
#  	 Newton-Raphson solver :  4/10. Error: 4.48E-16
# Solving timestep 200 / 200
#  	 Newton-Raphson solver :  1/10. Error: 1.99E-03
#  	 Newton-Raphson solver :  2/10. Error: 7.99E-08
#  	 Newton-Raphson solver :  3/10. Error: 3.28E-12
#  	 Newton-Raphson solver :  4/10. Error: 3.41E-16
# C:\Users\Jaime\Anaconda3\lib\site-packages\matplotlib\figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# <a id="ex3" ></a>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()

# I am using the style sheet found here  Lorena Barba https://github.com/barbagroup/CFDPython/blob/master/styles/custom.css
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
# 	h4{
# 		font-family: 'Fenix', serif;
#        }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render{
#         font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro";
# 			font-size: 90%;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
# 		line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
