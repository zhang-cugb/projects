# %% [markdown]
# # Two Phase Flow Examples

# %% [markdown]
# <a id = "table"></a>

# %% [markdown]
# ## Examples
#
# [Example 1. One injector, one producer well.](#ex1)
#
# <img src=".\images\2ph_ex1_sw.gif" width=400>
# <img src=".\images\2ph_ex1_po.gif" width=400>

# %% [markdown]
# <a id = "ex1"></a>

# %%
from modules.simulator.simulator import *
from modules.simulator.two_phase_flow import *
from modules.simulator.simplots import *
from modules.simulator.units import UnitRegistry
import numpy as np


# Set image folder path
imgpath = ".\\images"
# Units
u = UnitRegistry()

# %%
# The fluid is the same for both cases

# %% [markdown]
# ## [Example 1. One injector and  one producer well.](#table)
#
#
# One layer with 15 by 15 cells, with one water injector in the bottom layer and one oil producer in the top layer. The simulation is run for 10 days, with the Fully Implicit Method.

# %%
# GRID
Nx, Ny, Nz = np.array([10, 10, 2])
Sx, Sy, Sz = np.array([30, 30, 30]) * u.feet

depth = np.hstack((Sz * 0 * np.ones([Nx * Ny, ]), 
                  Sz * 1 * np.ones([Nx * Ny, ])))
                
grid = uniformCartesianGrid(Nx, Ny, Nz, Sx, Sy, Sz, depth)

# ROCK
perm = 100 * np.ones([grid.cellnumber, ]) * u.milli * u.darcy
poro = 0.15 * np.ones([grid.cellnumber, ])
# Rock compressibility equal for all cells
cr = 3E-6 / u.psi
porofunc = lambda p: poro * np.exp(cr * (p - 2800 * u.psi))
rock = Rock(perm, poro, cr, porofunc)

#  FLUID
# Oil phase
cf_o = 1E-5 / u.psi
miu_o = lambda p: ( -6E-5 * (p / u.psi) + 1.1791 ) * u.centi * u.poise
rho_o = lambda p: 45 * np.exp(cf_o * (p - 2800 * u.psi)) * u.pound / u.feet**3
fvf_o = lambda p : -1E-5 * (p / u.psi) + 1.018
# Water phase
cf_w = 3E-6 / u.psi
miu_w = lambda p: 1 * np.exp(5E-5 * (p / u.psi - 2800)) * u.centi * u.poise
#miu_w = lambda p: (1 +  5E-5 * (p / u.psi - 2800)) * u.centi * u.poise
rho_w = lambda p: 62.4 * np.exp(cf_w * (p - 2800 * u.psi)) * u.pound / u.feet**3
fvf_w = lambda p: 1 * np.exp(-3E-6 * (p / u.psi - 2800 ))   # adimensional

# Relative permeability functions
Swr = 0.25
Sor = 0.30
Swmin = Swr
Somin = Sor
Korw = 0.08
Koro = 0.7
Swmax = 1 - Somin
Somax = 1 - Swmin

kr_o = lambda So: Koro * ((So - Sor) / (1 - Sor - Swr)) ** 3
kr_w = lambda Sw: Korw * ((Sw - Swr) / (1 - Sor - Swr)) ** 2


dkr_o = lambda So: 3 * Koro  * (So - Sor) ** 2 / (1 - Sor - Swr) ** 3
dkr_w = lambda Sw: 2 * Korw * (Sw - Swr) / (1 - Sor - Swr) ** 2

def krwfunc(Sw):
    ''' Water relative permeambility
    Argument: Sw (np.array)'''
    kr = np.zeros_like(Sw)
    imin = Sw <= Swmin
    imax = Sw >= Swmax
    i = np.logical_not(np.logical_or(imin, imax))
    # The array is already filled with zeros    
    # kr[imin] = 0 
    kr[i] = kr_w(Sw[i])
    kr[imax] = Korw
    return kr

def krofunc(Sw):
    ''' Oil relative permeambility
    Argument: Sw (np.array)'''
    So = 1 - Sw
    kr = np.zeros_like(So)
    imin = So <= Somin
    imax = So >= Somax
    i = np.logical_not(np.logical_or(imin, imax))
    # The array is already filled with zeros
    # kr[imin] = 0
    kr[i] = kr_o(So[i])
    kr[imax] = Koro
    return kr


def d_krwfunc(Sw):
    ''' Water relative permeambility
    Argument: Sw (np.array)'''
    kr = np.zeros_like(Sw)
    imin = Sw <= Swmin
    imax = Sw >= Swmax
    i = np.logical_not(np.logical_or(imin, imax))
    # The array is already filled with zeros    
    # kr[imin] = 0 
    kr[i] = dkr_w(Sw[i])
    
    return kr

def d_krofunc(Sw):
    ''' Oil relative permeambility
    Argument: Sw (np.array)'''
    So = 1 - Sw
    kr = np.zeros_like(So)
    imin = So <= Somin
    imax = So >= Somax
    i = np.logical_not(np.logical_or(imin, imax))
    # The array is already filled with zeros
    # kr[imin] = 0
    kr[i] = dkr_o(So[i])
    
    return kr

# For this model, there is zero capillary pressure
pc = lambda Sw: 0 * Sw

fluid = blackOil((miu_o, miu_w), (rho_o, rho_w),
                 (fvf_o, fvf_w), (cf_o, cf_w), (krofunc, krwfunc), pc)

fluid.oilphase.d_kr = d_krofunc
fluid.waterphase.d_kr = d_krwfunc

# SCHEDULE
t1 = 0.1 * np.ones(100) * u.day
t2 = 0.5 * np.ones(100) * u.day
t3 = 1 * np.ones(50) * u.day
t4 = 2 * np.ones(50) * u.day
#t4 = 3 * np.ones(50) * u.day

timesteps = np.hstack((t1,t2,t3))
sch = Schedule(timesteps[:])

# BOUNDARY'S
boundary = Boundary()

# INITIAL CONDITIONS
p_init = 3000 * u.psi * np.ones([grid.cellnumber, ])
sw_init = 0.2 * np.ones([grid.cellnumber, ])

# WELLS
# Producer well
wells = Wells(grid, rock, fluid)
ci = Nx * Ny - 1
wells.add_vertical_well(0.35 * u.feet, ci, 2900 * u.psi, 0, 'Producer')
# Water injection well
source = np.zeros([grid.cellnumber * fluid.phasenumber, 1])
source[0] = -300 * u.barrel / u.day

# INITIALIZE SIMULATOR
FIM = ImplicitTwoPhase(
    grid, rock, fluid, wells, source, p_init, sw_init, boundary, gravity=True)

# RUN SIMULATION
results, well_solution, sch, info = FIM.solve(sch, max_iter= 10, tol = 1E-6, ATS = False)

## ========== Analysis of results ========================================

plotRateTwoPhase(wells, sch, imgpath)

# Cumulative production
rate = np.array(wells.wells[0]['rate_sol'][1]) / u.barrel * u.day
production = rate * (np.hstack((0, sch.timesteps)) / u.day)
cumproduction = production.cumsum()

print('Cumulative oil production after {:.3f} days is {:.3f} barrels.'.format(
    sch.tottime / u.day, cumproduction[-1]))

# Oil in place 
OIP = (grid.cellvolume * rock.poro * (1-sw_init)).sum()/u.barrel
# Non recoverable oil
NRO = (grid.cellvolume * rock.poro * (Sor)).sum()/u.barrel
# Percentage recovered
eff1 = cumproduction[-1]/OIP * 100
eff2 = cumproduction[-1]/(OIP - NRO) * 100

print('Oil recovered from OIP {:.3f} %. Oil recovered from recoverable oil {:.3f} %.'.format(eff1, eff2))
#=========================== Water cut ========================================
acum_sum = np.cumsum(sch.timesteps) / u.day
acum_sum = np.hstack((0, acum_sum))

oil_rate = np.array(wells.wells[0]['rate_sol'][1])
water_rate = np.array(wells.wells[0]['rate_sol'][0])
cut = water_rate / (oil_rate + water_rate)
water_bkt_time = acum_sum[np.argmax(cut>1*u.barrel)]
print('The breakthrough time is at {:.3f} days.'.format(water_bkt_time))
# Out:
# Solving timestep 1  / 250 	 0.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.27E-03
#  	 Newton-Raphson solver :  2/10. Error: 7.99E-16
# Solving timestep 2  / 250 	 0.100 days
#  	 Newton-Raphson solver :  1/10. Error: 3.06E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.79E-16
# Solving timestep 3  / 250 	 0.200 days
#  	 Newton-Raphson solver :  1/10. Error: 1.02E-03
#  	 Newton-Raphson solver :  2/10. Error: 4.37E-15
# Solving timestep 4  / 250 	 0.300 days
#  	 Newton-Raphson solver :  1/10. Error: 9.98E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.01E-15
# Solving timestep 5  / 250 	 0.400 days
#  	 Newton-Raphson solver :  1/10. Error: 7.50E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.20E-15
# Solving timestep 6  / 250 	 0.500 days
#  	 Newton-Raphson solver :  1/10. Error: 8.72E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.30E-15
# Solving timestep 7  / 250 	 0.600 days
#  	 Newton-Raphson solver :  1/10. Error: 1.14E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.29E-14
# Solving timestep 8  / 250 	 0.700 days
#  	 Newton-Raphson solver :  1/10. Error: 1.57E-03
#  	 Newton-Raphson solver :  2/10. Error: 5.32E-15
# Solving timestep 9  / 250 	 0.800 days
#  	 Newton-Raphson solver :  1/10. Error: 1.95E-03
#  	 Newton-Raphson solver :  2/10. Error: 2.15E-15
# Solving timestep 10 / 250 	 0.900 days
#  	 Newton-Raphson solver :  1/10. Error: 2.06E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.21E-15
# Solving timestep 11 / 250 	 1.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.87E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.41E-16
# Solving timestep 12 / 250 	 1.100 days
#  	 Newton-Raphson solver :  1/10. Error: 1.62E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.68E-16
# Solving timestep 13 / 250 	 1.200 days
#  	 Newton-Raphson solver :  1/10. Error: 1.46E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.52E-16
# Solving timestep 14 / 250 	 1.300 days
#  	 Newton-Raphson solver :  1/10. Error: 1.36E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.34E-16
# Solving timestep 15 / 250 	 1.400 days
#  	 Newton-Raphson solver :  1/10. Error: 8.79E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.05E-15
# Solving timestep 16 / 250 	 1.500 days
#  	 Newton-Raphson solver :  1/10. Error: 8.49E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.25E-15
# Solving timestep 17 / 250 	 1.600 days
#  	 Newton-Raphson solver :  1/10. Error: 7.66E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.41E-15
# Solving timestep 18 / 250 	 1.700 days
#  	 Newton-Raphson solver :  1/10. Error: 6.87E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.56E-15
# Solving timestep 19 / 250 	 1.800 days
#  	 Newton-Raphson solver :  1/10. Error: 6.11E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.73E-15
# Solving timestep 20 / 250 	 1.900 days
#  	 Newton-Raphson solver :  1/10. Error: 5.40E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.91E-15
# Solving timestep 21 / 250 	 2.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.75E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.11E-15
# Solving timestep 22 / 250 	 2.100 days
#  	 Newton-Raphson solver :  1/10. Error: 4.19E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.39E-15
# Solving timestep 23 / 250 	 2.200 days
#  	 Newton-Raphson solver :  1/10. Error: 3.72E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.80E-15
# Solving timestep 24 / 250 	 2.300 days
#  	 Newton-Raphson solver :  1/10. Error: 3.38E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.40E-15
# Solving timestep 25 / 250 	 2.400 days
#  	 Newton-Raphson solver :  1/10. Error: 3.17E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.33E-15
# Solving timestep 26 / 250 	 2.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.11E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.82E-15
# Solving timestep 27 / 250 	 2.600 days
#  	 Newton-Raphson solver :  1/10. Error: 3.20E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.27E-15
# Solving timestep 28 / 250 	 2.700 days
#  	 Newton-Raphson solver :  1/10. Error: 3.42E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.23E-14
# Solving timestep 29 / 250 	 2.800 days
#  	 Newton-Raphson solver :  1/10. Error: 3.73E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.78E-14
# Solving timestep 30 / 250 	 2.900 days
#  	 Newton-Raphson solver :  1/10. Error: 4.10E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.95E-14
# Solving timestep 31 / 250 	 3.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.47E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.45E-14
# Solving timestep 32 / 250 	 3.100 days
#  	 Newton-Raphson solver :  1/10. Error: 4.82E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.52E-15
# Solving timestep 33 / 250 	 3.200 days
#  	 Newton-Raphson solver :  1/10. Error: 5.10E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.39E-15
# Solving timestep 34 / 250 	 3.300 days
#  	 Newton-Raphson solver :  1/10. Error: 5.29E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.52E-15
# Solving timestep 35 / 250 	 3.400 days
#  	 Newton-Raphson solver :  1/10. Error: 5.37E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.39E-15
# Solving timestep 36 / 250 	 3.500 days
#  	 Newton-Raphson solver :  1/10. Error: 5.34E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.69E-15
# Solving timestep 37 / 250 	 3.600 days
#  	 Newton-Raphson solver :  1/10. Error: 5.22E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.25E-15
# Solving timestep 38 / 250 	 3.700 days
#  	 Newton-Raphson solver :  1/10. Error: 5.04E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.97E-15
# Solving timestep 39 / 250 	 3.800 days
#  	 Newton-Raphson solver :  1/10. Error: 4.81E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.79E-15
# Solving timestep 40 / 250 	 3.900 days
#  	 Newton-Raphson solver :  1/10. Error: 4.56E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.68E-15
# Solving timestep 41 / 250 	 4.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.32E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.61E-15
# Solving timestep 42 / 250 	 4.100 days
#  	 Newton-Raphson solver :  1/10. Error: 4.08E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.30E-15
# Solving timestep 43 / 250 	 4.200 days
#  	 Newton-Raphson solver :  1/10. Error: 2.22E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.94E-15
# Solving timestep 44 / 250 	 4.300 days
#  	 Newton-Raphson solver :  1/10. Error: 2.26E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.11E-15
# Solving timestep 45 / 250 	 4.400 days
#  	 Newton-Raphson solver :  1/10. Error: 2.13E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.02E-15
# Solving timestep 46 / 250 	 4.500 days
#  	 Newton-Raphson solver :  1/10. Error: 1.95E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.15E-15
# Solving timestep 47 / 250 	 4.600 days
#  	 Newton-Raphson solver :  1/10. Error: 1.78E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.39E-15
# Solving timestep 48 / 250 	 4.700 days
#  	 Newton-Raphson solver :  1/10. Error: 1.63E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.70E-15
# Solving timestep 49 / 250 	 4.800 days
#  	 Newton-Raphson solver :  1/10. Error: 1.14E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.80E-13
# Solving timestep 50 / 250 	 4.900 days
#  	 Newton-Raphson solver :  1/10. Error: 1.11E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.12E-15
# Solving timestep 51 / 250 	 5.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.07E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.87E-15
# Solving timestep 52 / 250 	 5.100 days
#  	 Newton-Raphson solver :  1/10. Error: 1.04E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.74E-14
# Solving timestep 53 / 250 	 5.200 days
#  	 Newton-Raphson solver :  1/10. Error: 1.04E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.98E-14
# Solving timestep 54 / 250 	 5.300 days
#  	 Newton-Raphson solver :  1/10. Error: 1.07E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.48E-14
# Solving timestep 55 / 250 	 5.400 days
#  	 Newton-Raphson solver :  1/10. Error: 1.12E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.05E-14
# Solving timestep 56 / 250 	 5.500 days
#  	 Newton-Raphson solver :  1/10. Error: 1.19E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.58E-14
# Solving timestep 57 / 250 	 5.600 days
#  	 Newton-Raphson solver :  1/10. Error: 1.35E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.88E-14
# Solving timestep 58 / 250 	 5.700 days
#  	 Newton-Raphson solver :  1/10. Error: 1.40E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.54E-14
# Solving timestep 59 / 250 	 5.800 days
#  	 Newton-Raphson solver :  1/10. Error: 1.50E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.45E-14
# Solving timestep 60 / 250 	 5.900 days
#  	 Newton-Raphson solver :  1/10. Error: 1.62E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.63E-14
# Solving timestep 61 / 250 	 6.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.75E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.73E-13
# Solving timestep 62 / 250 	 6.100 days
#  	 Newton-Raphson solver :  1/10. Error: 1.89E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.64E-14
# Solving timestep 63 / 250 	 6.200 days
#  	 Newton-Raphson solver :  1/10. Error: 2.03E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.09E-14
# Solving timestep 64 / 250 	 6.300 days
#  	 Newton-Raphson solver :  1/10. Error: 2.16E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.67E-14
# Solving timestep 65 / 250 	 6.400 days
#  	 Newton-Raphson solver :  1/10. Error: 2.30E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.56E-14
# Solving timestep 66 / 250 	 6.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.42E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.62E-14
# Solving timestep 67 / 250 	 6.600 days
#  	 Newton-Raphson solver :  1/10. Error: 2.52E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.93E-14
# Solving timestep 68 / 250 	 6.700 days
#  	 Newton-Raphson solver :  1/10. Error: 2.62E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.83E-14
# Solving timestep 69 / 250 	 6.800 days
#  	 Newton-Raphson solver :  1/10. Error: 2.69E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.16E-14
# Solving timestep 70 / 250 	 6.900 days
#  	 Newton-Raphson solver :  1/10. Error: 2.74E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.94E-14
# Solving timestep 71 / 250 	 7.000 days
#  	 Newton-Raphson solver :  1/10. Error: 2.76E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.51E-14
# Solving timestep 72 / 250 	 7.100 days
#  	 Newton-Raphson solver :  1/10. Error: 2.76E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.63E-14
# Solving timestep 73 / 250 	 7.200 days
#  	 Newton-Raphson solver :  1/10. Error: 2.74E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.66E-14
# Solving timestep 74 / 250 	 7.300 days
#  	 Newton-Raphson solver :  1/10. Error: 2.69E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.87E-15
# Solving timestep 75 / 250 	 7.400 days
#  	 Newton-Raphson solver :  1/10. Error: 2.63E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.66E-15
# Solving timestep 76 / 250 	 7.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.56E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.47E-15
# Solving timestep 77 / 250 	 7.600 days
#  	 Newton-Raphson solver :  1/10. Error: 2.47E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.72E-15
# Solving timestep 78 / 250 	 7.700 days
#  	 Newton-Raphson solver :  1/10. Error: 2.38E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.23E-15
# Solving timestep 79 / 250 	 7.800 days
#  	 Newton-Raphson solver :  1/10. Error: 2.29E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.40E-15
# Solving timestep 80 / 250 	 7.900 days
#  	 Newton-Raphson solver :  1/10. Error: 1.82E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.67E-14
# Solving timestep 81 / 250 	 8.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.88E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.50E-15
# Solving timestep 82 / 250 	 8.100 days
#  	 Newton-Raphson solver :  1/10. Error: 1.84E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.93E-15
# Solving timestep 83 / 250 	 8.200 days
#  	 Newton-Raphson solver :  1/10. Error: 1.78E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.26E-15
# Solving timestep 84 / 250 	 8.300 days
#  	 Newton-Raphson solver :  1/10. Error: 1.72E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.98E-15
# Solving timestep 85 / 250 	 8.400 days
#  	 Newton-Raphson solver :  1/10. Error: 1.67E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.85E-15
# Solving timestep 86 / 250 	 8.500 days
#  	 Newton-Raphson solver :  1/10. Error: 1.62E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.81E-15
# Solving timestep 87 / 250 	 8.600 days
#  	 Newton-Raphson solver :  1/10. Error: 1.58E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.82E-15
# Solving timestep 88 / 250 	 8.700 days
#  	 Newton-Raphson solver :  1/10. Error: 1.55E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.81E-15
# Solving timestep 89 / 250 	 8.800 days
#  	 Newton-Raphson solver :  1/10. Error: 1.29E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.56E-15
# Solving timestep 90 / 250 	 8.900 days
#  	 Newton-Raphson solver :  1/10. Error: 1.36E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.55E-14
# Solving timestep 91 / 250 	 9.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.38E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.18E-14
# Solving timestep 92 / 250 	 9.100 days
#  	 Newton-Raphson solver :  1/10. Error: 1.39E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.20E-13
# Solving timestep 93 / 250 	 9.200 days
#  	 Newton-Raphson solver :  1/10. Error: 1.39E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.64E-13
# Solving timestep 94 / 250 	 9.300 days
#  	 Newton-Raphson solver :  1/10. Error: 1.40E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.45E-12
# Solving timestep 95 / 250 	 9.400 days
#  	 Newton-Raphson solver :  1/10. Error: 1.30E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.53E-15
# Solving timestep 96 / 250 	 9.500 days
#  	 Newton-Raphson solver :  1/10. Error: 1.36E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.76E-14
# Solving timestep 97 / 250 	 9.600 days
#  	 Newton-Raphson solver :  1/10. Error: 1.39E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.83E-14
# Solving timestep 98 / 250 	 9.700 days
#  	 Newton-Raphson solver :  1/10. Error: 1.42E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.44E-13
# Solving timestep 99 / 250 	 9.800 days
#  	 Newton-Raphson solver :  1/10. Error: 1.44E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.28E-13
# Solving timestep 100 / 250 	 9.900 days
#  	 Newton-Raphson solver :  1/10. Error: 1.45E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.39E-14
# Solving timestep 101 / 250 	 10.000 days
#  	 Newton-Raphson solver :  1/10. Error: 2.73E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.32E-13
# Solving timestep 102 / 250 	 10.500 days
#  	 Newton-Raphson solver :  1/10. Error: 1.50E-03
#  	 Newton-Raphson solver :  2/10. Error: 8.40E-15
# Solving timestep 103 / 250 	 11.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.20E-03
#  	 Newton-Raphson solver :  2/10. Error: 9.40E-15
# Solving timestep 104 / 250 	 11.500 days
#  	 Newton-Raphson solver :  1/10. Error: 1.02E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.41E-14
# Solving timestep 105 / 250 	 12.000 days
#  	 Newton-Raphson solver :  1/10. Error: 9.49E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.51E-14
# Solving timestep 106 / 250 	 12.500 days
#  	 Newton-Raphson solver :  1/10. Error: 8.27E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.26E-12
# Solving timestep 107 / 250 	 13.000 days
#  	 Newton-Raphson solver :  1/10. Error: 9.05E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.33E-15
# Solving timestep 108 / 250 	 13.500 days
#  	 Newton-Raphson solver :  1/10. Error: 8.53E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.11E-13
# Solving timestep 109 / 250 	 14.000 days
#  	 Newton-Raphson solver :  1/10. Error: 9.27E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.38E-14
# Solving timestep 110 / 250 	 14.500 days
#  	 Newton-Raphson solver :  1/10. Error: 8.97E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.24E-14
# Solving timestep 111 / 250 	 15.000 days
#  	 Newton-Raphson solver :  1/10. Error: 8.44E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.32E-14
# Solving timestep 112 / 250 	 15.500 days
#  	 Newton-Raphson solver :  1/10. Error: 7.83E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.80E-14
# Solving timestep 113 / 250 	 16.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.52E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.62E-14
# Solving timestep 114 / 250 	 16.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.81E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.85E-14
# Solving timestep 115 / 250 	 17.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.90E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.64E-13
# Solving timestep 116 / 250 	 17.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.78E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.01E-13
# Solving timestep 117 / 250 	 18.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.30E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.14E-14
# Solving timestep 118 / 250 	 18.500 days
#  	 Newton-Raphson solver :  1/10. Error: 7.06E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.64E-15
# Solving timestep 119 / 250 	 19.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.06E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.55E-14
# Solving timestep 120 / 250 	 19.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.65E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.33E-12
# Solving timestep 121 / 250 	 20.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.74E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.19E-13
# Solving timestep 122 / 250 	 20.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.71E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.74E-14
# Solving timestep 123 / 250 	 21.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.03E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.14E-14
# Solving timestep 124 / 250 	 21.500 days
#  	 Newton-Raphson solver :  1/10. Error: 5.45E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.22E-14
# Solving timestep 125 / 250 	 22.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.93E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.70E-14
# Solving timestep 126 / 250 	 22.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.47E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.90E-13
# Solving timestep 127 / 250 	 23.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.47E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.52E-13
# Solving timestep 128 / 250 	 23.500 days
#  	 Newton-Raphson solver :  1/10. Error: 7.16E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.96E-14
# Solving timestep 129 / 250 	 24.000 days
#  	 Newton-Raphson solver :  1/10. Error: 7.77E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.48E-14
# Solving timestep 130 / 250 	 24.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.29E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.25E-13
# Solving timestep 131 / 250 	 25.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.97E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.53E-14
# Solving timestep 132 / 250 	 25.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.14E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.08E-14
# Solving timestep 133 / 250 	 26.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.51E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.23E-14
# Solving timestep 134 / 250 	 26.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.24E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.10E-14
# Solving timestep 135 / 250 	 27.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.36E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.83E-14
# Solving timestep 136 / 250 	 27.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.22E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.41E-14
# Solving timestep 137 / 250 	 28.000 days
#  	 Newton-Raphson solver :  1/10. Error: 2.98E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.23E-13
# Solving timestep 138 / 250 	 28.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.81E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.97E-13
# Solving timestep 139 / 250 	 29.000 days
#  	 Newton-Raphson solver :  1/10. Error: 2.80E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.53E-13
# Solving timestep 140 / 250 	 29.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.04E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.48E-14
# Solving timestep 141 / 250 	 30.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.59E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.53E-14
# Solving timestep 142 / 250 	 30.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.63E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.05E-14
# Solving timestep 143 / 250 	 31.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.94E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.73E-14
# Solving timestep 144 / 250 	 31.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.35E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.40E-14
# Solving timestep 145 / 250 	 32.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.84E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.52E-14
# Solving timestep 146 / 250 	 32.500 days
#  	 Newton-Raphson solver :  1/10. Error: 5.36E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.68E-13
# Solving timestep 147 / 250 	 33.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.86E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.42E-14
# Solving timestep 148 / 250 	 33.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.28E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.42E-14
# Solving timestep 149 / 250 	 34.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.59E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.72E-14
# Solving timestep 150 / 250 	 34.500 days
#  	 Newton-Raphson solver :  1/10. Error: 6.01E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.27E-14
# Solving timestep 151 / 250 	 35.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.18E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.04E-14
# Solving timestep 152 / 250 	 35.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.15E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.12E-14
# Solving timestep 153 / 250 	 36.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.56E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.51E-14
# Solving timestep 154 / 250 	 36.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.75E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.01E-14
# Solving timestep 155 / 250 	 37.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.71E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.56E-14
# Solving timestep 156 / 250 	 37.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.01E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.01E-13
# Solving timestep 157 / 250 	 38.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.03E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.09E-13
# Solving timestep 158 / 250 	 38.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.65E-04
#  	 Newton-Raphson solver :  2/10. Error: 5.03E-14
# Solving timestep 159 / 250 	 39.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.63E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.84E-13
# Solving timestep 160 / 250 	 39.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.56E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.06E-13
# Solving timestep 161 / 250 	 40.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.47E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.38E-13
# Solving timestep 162 / 250 	 40.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.43E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.03E-13
# Solving timestep 163 / 250 	 41.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.43E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.37E-13
# Solving timestep 164 / 250 	 41.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.12E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.88E-14
# Solving timestep 165 / 250 	 42.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.30E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.52E-13
# Solving timestep 166 / 250 	 42.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.54E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.39E-14
# Solving timestep 167 / 250 	 43.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.42E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.74E-14
# Solving timestep 168 / 250 	 43.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.71E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.79E-14
# Solving timestep 169 / 250 	 44.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.03E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.17E-14
# Solving timestep 170 / 250 	 44.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.33E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.82E-14
# Solving timestep 171 / 250 	 45.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.58E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.72E-14
# Solving timestep 172 / 250 	 45.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.57E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.99E-14
# Solving timestep 173 / 250 	 46.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.90E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.31E-14
# Solving timestep 174 / 250 	 46.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.94E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.66E-14
# Solving timestep 175 / 250 	 47.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.38E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.54E-14
# Solving timestep 176 / 250 	 47.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.36E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.00E-14
# Solving timestep 177 / 250 	 48.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.32E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.71E-14
# Solving timestep 178 / 250 	 48.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.26E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.90E-14
# Solving timestep 179 / 250 	 49.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.21E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.26E-14
# Solving timestep 180 / 250 	 49.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.61E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.07E-14
# Solving timestep 181 / 250 	 50.000 days
#  	 Newton-Raphson solver :  1/10. Error: 2.72E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.90E-14
# Solving timestep 182 / 250 	 50.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.63E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.57E-14
# Solving timestep 183 / 250 	 51.000 days
#  	 Newton-Raphson solver :  1/10. Error: 2.73E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.36E-13
# Solving timestep 184 / 250 	 51.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.95E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.02E-14
# Solving timestep 185 / 250 	 52.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.17E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.68E-14
# Solving timestep 186 / 250 	 52.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.41E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.65E-14
# Solving timestep 187 / 250 	 53.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.67E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.00E-13
# Solving timestep 188 / 250 	 53.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.95E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.63E-13
# Solving timestep 189 / 250 	 54.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.23E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.24E-13
# Solving timestep 190 / 250 	 54.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.19E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.23E-11
# Solving timestep 191 / 250 	 55.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.11E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.19E-12
# Solving timestep 192 / 250 	 55.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.48E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.43E-14
# Solving timestep 193 / 250 	 56.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.67E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.62E-14
# Solving timestep 194 / 250 	 56.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.73E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.34E-14
# Solving timestep 195 / 250 	 57.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.71E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.21E-14
# Solving timestep 196 / 250 	 57.500 days
#  	 Newton-Raphson solver :  1/10. Error: 4.62E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.14E-14
# Solving timestep 197 / 250 	 58.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.88E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.03E-14
# Solving timestep 198 / 250 	 58.500 days
#  	 Newton-Raphson solver :  1/10. Error: 3.31E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.38E-13
# Solving timestep 199 / 250 	 59.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.05E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.19E-13
# Solving timestep 200 / 250 	 59.500 days
#  	 Newton-Raphson solver :  1/10. Error: 2.75E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.44E-14
# Solving timestep 201 / 250 	 60.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.59E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.95E-14
# Solving timestep 202 / 250 	 61.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.45E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.75E-13
# Solving timestep 203 / 250 	 62.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.50E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.24E-14
# Solving timestep 204 / 250 	 63.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.96E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.58E-14
# Solving timestep 205 / 250 	 64.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.29E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.79E-14
# Solving timestep 206 / 250 	 65.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.89E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.85E-13
# Solving timestep 207 / 250 	 66.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.87E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.24E-13
# Solving timestep 208 / 250 	 67.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.26E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.69E-14
# Solving timestep 209 / 250 	 68.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.06E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.94E-14
# Solving timestep 210 / 250 	 69.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.57E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.31E-13
# Solving timestep 211 / 250 	 70.000 days
#  	 Newton-Raphson solver :  1/10. Error: 8.42E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.01E-14
# Solving timestep 212 / 250 	 71.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.02E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.92E-14
# Solving timestep 213 / 250 	 72.000 days
#  	 Newton-Raphson solver :  1/10. Error: 1.17E-03
#  	 Newton-Raphson solver :  2/10. Error: 1.34E-14
# Solving timestep 214 / 250 	 73.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.16E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.55E-14
# Solving timestep 215 / 250 	 74.000 days
#  	 Newton-Raphson solver :  1/10. Error: 7.98E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.06E-14
# Solving timestep 216 / 250 	 75.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.32E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.01E-14
# Solving timestep 217 / 250 	 76.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.43E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.16E-14
# Solving timestep 218 / 250 	 77.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.05E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.74E-13
# Solving timestep 219 / 250 	 78.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.05E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.20E-13
# Solving timestep 220 / 250 	 79.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.57E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.74E-13
# Solving timestep 221 / 250 	 80.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.03E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.77E-14
# Solving timestep 222 / 250 	 81.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.53E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.96E-14
# Solving timestep 223 / 250 	 82.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.53E-04
#  	 Newton-Raphson solver :  2/10. Error: 9.72E-13
# Solving timestep 224 / 250 	 83.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.22E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.46E-14
# Solving timestep 225 / 250 	 84.000 days
#  	 Newton-Raphson solver :  1/10. Error: 6.79E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.26E-14
# Solving timestep 226 / 250 	 85.000 days
#  	 Newton-Raphson solver :  1/10. Error: 7.14E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.52E-14
# Solving timestep 227 / 250 	 86.000 days
#  	 Newton-Raphson solver :  1/10. Error: 7.30E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.21E-14
# Solving timestep 228 / 250 	 87.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.90E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.47E-14
# Solving timestep 229 / 250 	 88.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.95E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.99E-13
# Solving timestep 230 / 250 	 89.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.76E-04
#  	 Newton-Raphson solver :  2/10. Error: 7.34E-14
# Solving timestep 231 / 250 	 90.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.59E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.74E-14
# Solving timestep 232 / 250 	 91.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.53E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.35E-13
# Solving timestep 233 / 250 	 92.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.30E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.20E-13
# Solving timestep 234 / 250 	 93.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.51E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.12E-14
# Solving timestep 235 / 250 	 94.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.62E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.61E-14
# Solving timestep 236 / 250 	 95.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.79E-04
#  	 Newton-Raphson solver :  2/10. Error: 8.16E-14
# Solving timestep 237 / 250 	 96.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.88E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.16E-13
# Solving timestep 238 / 250 	 97.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.90E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.32E-13
# Solving timestep 239 / 250 	 98.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.46E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.33E-14
# Solving timestep 240 / 250 	 99.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.19E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.08E-13
# Solving timestep 241 / 250 	 100.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.80E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.63E-13
# Solving timestep 242 / 250 	 101.000 days
#  	 Newton-Raphson solver :  1/10. Error: 7.22E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.43E-14
# Solving timestep 243 / 250 	 102.000 days
#  	 Newton-Raphson solver :  1/10. Error: 8.28E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.00E-14
# Solving timestep 244 / 250 	 103.000 days
#  	 Newton-Raphson solver :  1/10. Error: 7.92E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.97E-14
# Solving timestep 245 / 250 	 104.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.17E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.99E-13
# Solving timestep 246 / 250 	 105.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.04E-04
#  	 Newton-Raphson solver :  2/10. Error: 1.28E-13
# Solving timestep 247 / 250 	 106.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.52E-04
#  	 Newton-Raphson solver :  2/10. Error: 2.81E-14
# Solving timestep 248 / 250 	 107.000 days
#  	 Newton-Raphson solver :  1/10. Error: 5.16E-04
#  	 Newton-Raphson solver :  2/10. Error: 3.75E-14
# Solving timestep 249 / 250 	 108.000 days
#  	 Newton-Raphson solver :  1/10. Error: 4.86E-04
#  	 Newton-Raphson solver :  2/10. Error: 4.42E-14
# Solving timestep 250 / 250 	 109.000 days
#  	 Newton-Raphson solver :  1/10. Error: 3.06E-04
#  	 Newton-Raphson solver :  2/10. Error: 6.39E-14
# Cumulative oil production after 110.000 days is 34030.751 barrels.
# C:\Users\Jaime\Documents\Jupyter_Notebooks\Portfolio\modules\simulator\simplots.py:249: RuntimeWarning: invalid value encountered in true_divide
#   cut = water_rate / (oil_rate + water_rate)
# C:\Users\Jaime\Anaconda3\lib\site-packages\ipykernel\__main__.py:172: RuntimeWarning: invalid value encountered in true_divide
# Oil recovered from OIP 29.486 %. Oil recovered from recoverable oil 47.177 %.
# The breakthrough time is at 0.000 days.
# C:\Users\Jaime\Anaconda3\lib\site-packages\ipykernel\__main__.py:173: RuntimeWarning: invalid value encountered in greater

# %%
# PLOT and make a gif with ffmpeg
#Transform results to psi
p_oil = results['p_oil'][:,:]/ u.psi
sw = results['sw'][:,:]

for k in np.arange(0, acum_sum.size, 1):
    plotCellValues2D(grid, p_oil[:, k], 'inferno', np.min(p_oil), np.max(p_oil),
                     title='Oil pressure. {:.3f} days'.format(acum_sum[k]), 
                     filename='{}\\2ph_ex1_po_{}'.format(imgpath,k))

for k in np.arange(0, acum_sum.size, 1):
    plotCellValues2D(grid, sw[:, k], 'plasma', np.min(sw), np.max(sw),
                     title='Water saturation. {:.3f} days'.format(acum_sum[k]), 
                     filename='{}\\2ph_ex1_sw_{}'.format(imgpath,k))
# Out:
# C:\Users\Jaime\Anaconda3\lib\site-packages\matplotlib\figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# <a id = "ex2"></a>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()

# Using the style sheet found here  Lorena Barba /* https://github.com/barbagroup/CFDPython/blob/master/styles/custom.css */
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
# 	h4{
# 		font-family: 'Fenix', serif;
#        }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render{
#         font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro";
# 			font-size: 90%;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
# 		line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
